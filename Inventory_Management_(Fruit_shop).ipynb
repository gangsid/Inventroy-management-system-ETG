# %%
import json 
from random import randint
import time
x = randint(100000, 1000000)
Time = time.ctime()

# %% [markdown]
# ### ENTER CUSTOMER DETAILS

# %%
print("Hello and welcome to the SID's Basket ")



print(" Please enter your full name : ")
NameOfCustomer = input()
print(" Please enter your 10 digit phone number: ")
PhoneNO_OfCustomer = int(input())
print(" Please enter your Gender(Male, Female or Others) : ")
GenderOfCustomer = input()
print(" Please enter your Address : ")
AddressOfCustomer = input()

# %%
print(f"Hii {NameOfCustomer} and welcome, your number is {PhoneNO_OfCustomer} and your gender is {GenderOfCustomer} and you live in {AddressOfCustomer} : Please check your details. In case of descrepency please restart the terminal  ")

# %% [markdown]
# ### INVENTORY OF APPLES AND MANGOES(RUN ONLY ONE TIME)

# %%
fruits = {
    
       "Apple_var1"  :  {"Name" : "Himachali apple", "Origin" : "Himachal pradesh", "Color" : "Red", "Rating" : 4.9, "Price per kg" : 100},
       "Apple_var2"  :  {"Name" : "Shimla apple", "Origin" : "Shimla", "Color" : "Red", "Rating" : 4.7, "Price per kg" : 85},
       "Apple_var3"  :  {"Name" : "Green", "Origin" : "Australia", "Color" : "Green", "Rating" : 4.9, "Price per kg" : 120},
       "Apple_var4"  :  {"Name" : "Golden Delicious", "Origin" : "USA", "Color" : "Pale Yellow", "Rating" : 4.8, "Price per kg" : 200},
       "Apple_var5"  :  {"Name" : "Airlie Red Flesh", "Origin" : "Oregon", "Color" : "Pale Red", "Rating" : 4.7, "Price per kg" : 150},
       "Apple_var6"  :  {"Name" : "Fuji", "Origin" : "Fujisaki", "Color" : "Light Red", "Rating" : 4.5, "Price per kg" : 75},
       "Apple_var7"  :  {"Name" : "Cripps Pink", "Origin" : "Western Australia", "Color" : "Pink-Red", "Rating" : 4.7, "Price per kg" : 110},
       "Apple_var8"  :  {"Name" : "Honeycrisp", "Origin" : "Twin Cities", "Color" : "Pale Red", "Rating" : 4.5, "Price per kg" : 90},
       "Apple_var9"  :  {"Name" : "Envy", "Origin" : "New Zealand", "Color" : "Red", "Rating" : 4.9, "Price per kg" : 180},
       "Apple_var10"  :  {"Name" : "Gala", "Origin" : "New Zealand", "Color" : "Pale Red", "Rating" : 4.9, "Price per kg" : 250},
       "Apple_var11"  :  {"Name" : "Pazazz", "Origin" : "Minnesota", "Color" : "Red", "Rating" : 4.2, "Price per kg" : 50},
       "Apple_var12"  :  {"Name" : "Jazz", "Origin" : "New Zealand", "Color" : "Yellow-Red", "Rating" : 4.7, "Price per kg" : 150},
       "Apple_var13"  :  {"Name" : "Red Delicious", "Origin" : "Iowa", "Color" : "Dark Red", "Rating" : 4.9, "Price per kg" : 350},
       "Apple_var14"  :  {"Name" : "Braeburn", "Origin" : "New Zealand", "Color" : "Pale Red", "Rating" : 4.7, "Price per kg" : 90},
       "Apple_var15"  :  {"Name" : "Hidden rose", "Origin" : "Oregon", "Color" : "vibrant pink", "Rating" : 4.9, "Price per kg" : 400},
       "Mango_var1"  :  {"Name" : "Alphonso Mangoes", "Origin" : "Maharashtra", "Color" : "Reddish green", "Rating" : 4.9, "Price per kg" : 1000},
       "Mango_var2"  :  {"Name" : "Kesar Mangoes", "Origin" : "Gujarat", "Color" : "Light Green", "Rating" : 4.8, "Price per kg" : 950},
       "Mango_var3"  :  {"Name" : "Dasheri Mangoes", "Origin" : "Uttar Pradesh", "Color" : "Green", "Rating" : 4.9, "Price per kg" : 1200},
       "Mango_var4"  :  {"Name" : "Himsagar and Kishan Bhog Mangoes", "Origin" : " West Bengal", "Color" : "Green", "Rating" : 4.4, "Price per kg" : 750},
       "Mango_var5"  :  {"Name" : "Chausa Mangoes", "Origin" : "Uttar Pradesh", "Color" : "Yellow", "Rating" : 4.9, "Price per kg" : 1000},
       "Mango_var6"  :  {"Name" : "Badami Mangoes", "Origin" : "North Karnataka", "Color" : "Yellow green", "Rating" : 4.4, "Price per kg" : 1000},
       "Mango_var7"  :  {"Name" : "Safeda Mangoes ", "Origin" : "Andhra Pradesh", "Color" : "Golden", "Rating" : 4.9, "Price per kg" : 1500},
       "Mango_var8"  :  {"Name" : "Fazli Mangoes", "Origin" : " Bihar/West Bengal", "Color" : "Green", "Rating" : 4.5, "Price per kg" : 800},
       "Mango_var9"  :  {"Name" : "Bombay Green Mangoes", "Origin" : "Punjab", "Color" : "Green", "Rating" : 4.9, "Price per kg" : 1000},
       "Mango_var10"  :  {"Name" : "Langra Mangoes", "Origin" : "Uttar Pradesh", "Color" : "Green", "Rating" : 4.8, "Price per kg" : 1200},
       "Mango_var11"  :  {"Name" : "Totapuri Mangoes ", "Origin" : "Karnataka", "Color" : "Yellow Green", "Rating" : 4.9, "Price per kg" : 1500},
       "Mango_var12"  :  {"Name" : "Neelam Mangoes ", "Origin" : "Andhra Pradesh", "Color" : "Yellow Green", "Rating" : 4.9, "Price per kg" : 2000},
       "Mango_var13"  :  {"Name" : "Raspuri Mangoes", "Origin" : "Karnataka", "Color" : "Green", "Rating" : 4.9, "Price per kg" : 1700},
       "Mango_var14"  :  {"Name" : "Mulgoba Mangoes", "Origin" : "Tamil Nadu", "Color" : "Red Green", "Rating" : 4.5, "Price per kg" : 1000},
       "Mango_var15"  :  {"Name" : "Lakshmanbhog Mangoes ", "Origin" : "West Bengal", "Color" : "Orange", "Rating" : 4.9, "Price per kg" : 2500}
       

}

# %%
Records = json.dumps(fruits)

gd = open("Records.json", "w")
gd.write(Records)
gd.close()

# %%
gd = open("Records.json", "r")
txt = gd.read()
gd.close()

# %%
Fruits = json.loads(txt)
Fruits

# %% [markdown]
# ### PURCHASE HERE

# %%
BILL = {}
print("we have apples and mangoes available  ")
print("What would you like to buy(apples/mangoes) ")
fruit_buy = input()
if (fruit_buy == 'apples'):
  print("We have these variety available : ")
  print(Fruits['Apple_var1'], Fruits['Apple_var2'],  Fruits['Apple_var3'],  Fruits['Apple_var4'],  Fruits['Apple_var5'], Fruits['Apple_var6'], Fruits['Apple_var7'], Fruits['Apple_var8'], Fruits['Apple_var9'], Fruits['Apple_var10'], Fruits['Apple_var11'], Fruits['Apple_var12'], Fruits['Apple_var13'], Fruits['Apple_var14'], Fruits['Apple_var15'])
  apple_buy = input("Please select only one item with exact name : ")
  i = int(input("How much kg? :"))
  if(apple_buy == 'Himachali apple'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {100*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (100*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Shimla apple'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {85*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (85*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Green'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {120*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (120*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Golden Delicious'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {200*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (200*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Airlie Red Flesh'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {150*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (150*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Fuji'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {75*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (75*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Cripps Pink'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {110*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (110*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")


  elif(apple_buy == 'Honeycrisp'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {90*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (90*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Envy'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {180*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (180*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Gala'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {250*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (250*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Pazazz'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {50*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (50*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Jazz'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {150*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (150*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Red Delicious'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {350*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (350*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Braeburn'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {90*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (90*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(apple_buy == 'Hidden rose'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {apple_buy}\n Total amount(INR): {400*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : apple_buy})
    BILL.update({"Total amount(INR)": (400*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")


###############################################################################################################################################################################################################################################################



elif(fruit_buy == 'mangoes'):
  print("We have these variety available : ")
  print(Fruits['Mango_var1'], Fruits['Mango_var2'],  Fruits['Mango_var3'],  Fruits['Mango_var4'],  Fruits['Mango_var5'], Fruits['Mango_var6'], Fruits['Mango_var7'], Fruits['Mango_var8'], Fruits['Mango_var9'], Fruits['Mango_var10'], Fruits['Mango_var11'], Fruits['Mango_var12'], Fruits['Mango_var13'], Fruits['Mango_var14'], Fruits['Mango_var15'])
  mango_buy = input("Please select only one item with exact name : ")
  i = int(input("How much kg? :"))
  if(mango_buy == 'Alphonso Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Kesar Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {950*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (950*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Dasheri Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1200*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1200*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Himsagar and Kishan Bhog Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {750*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (750*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Chausa Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Badami Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Safeda Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1500*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1500*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Fazli Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {800*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (800*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Bombay Green Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Langra Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1200*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1200*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Totapuri Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1500*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1500*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Neelam Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {2000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (2000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Raspuri Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1700*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1700*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Mulgoba Mangoe'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {1000*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (1000*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

  elif(mango_buy == 'Lakshmanbhog Mangoes'):
    print("Thanks for your purchase your bill is")
    print("***************************************************************************")
    print(f"Name of the customer :{NameOfCustomer}\n Product bought: {mango_buy}\n Total amount(INR): {2500*i}\n Transaction id is = {x} \n \n")
    BILL.update({"Name of the customer" : NameOfCustomer})
    BILL.update({"Product bought" : mango_buy})
    BILL.update({"Total amount(INR)": (2500*i)})
    BILL.update({"Transaction id is" : x})
    BILL.update({"Time" : Time})
    print("***************************************************************************")

else:
  print("Invalid name")

# %% [markdown]
# ##PRINT BILL AND SAVE IT TO SALES JSON FILE

# %%
BILL

# %%
js = json.dumps(BILL)

# %%
js

# %%
fd = open("Sales.json", "a")
fd.write(js)
fd.close()
